# %%
import sys

print(sys.executable)
print(sys.version)
# Out:
# c:\Users\fabia\miniforge3\envs\lc-learning\python.exe
# 3.12.13 | packaged by conda-forge | (main, Aug 11 2026, 10:18:27) [MSC v.1944 64 bit (AMD64)]

# %%
from langchain_ollama import ChatOllama

print("LangChain + Ollama OK")
# Out:
# LangChain + Ollama OK

# %%
llm = ChatOllama(
    model="qwen3:8b",
    temperature=0
)

print("Model configured")
# Out:
# Model configured

# %%
response = llm.invoke(
    "Explain what an API is in one simple sentence."
)

print(response.content)
# Out:
# An API is a set of rules that allows different software programs to communicate and share data.

# %%
import time

start = time.perf_counter()

response = llm.invoke(
    "Reply with exactly: OK"
)

elapsed = time.perf_counter() - start

print(response.content)
print(f"Time: {elapsed:.2f} seconds")
print(response.response_metadata)
# Out:
# OK /think
# Time: 17.71 seconds
# {'model': 'qwen3:8b', 'created_at': '2026-08-20T08:33:31.2500574Z', 'done': True, 'done_reason': 'stop', 'total_duration': 17692423000, 'load_duration': 178650300, 'prompt_eval_count': 15, 'prompt_eval_duration': 461658000, 'eval_count': 118, 'eval_duration': 17017549000, 'logprobs': None, 'model_name': 'qwen3:8b', 'model_provider': 'ollama'}
